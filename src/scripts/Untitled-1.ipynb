# %%
from pathlib import Path
import pandas as pd

# %%
df_path = Path("local_data/AUDACE/data/derivatives/stress_class/abs_feat_df.csv")
df = pd.read_csv(df_path)

# %%
(360*2)/30
# Out:
# 24.0

# %%
# get number of data points per signal as a function of task
df[df["Task"]!="NOISE"].groupby(["Rest", "Signal"]).count()
# Out:
#                   Participant  Task  SubSegIdx  HRV_MeanNN  HRV_SDNN
# Rest   Signal
# Rest   ECG                 60    60         60          60        60  \
#        ECG-IEMLe          360   360        360         360       360
#        ECG-IEMRe          360   360        360         360       360
#        IEML                60    60         60          60        60
#        IEMR                60    60         60          60        60
# Stress ECG                 60    60         60          60        60
#        ECG-IEMLe          360   360        360         360       360
#        ECG-IEMRe          360   360        360         360       360
#        IEML                60    60         60          60        60
#        IEMR                60    60         60          60        60
#
#                   HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  HRV_SDANN5
# Rest   Signal
# Rest   ECG                60          60           0           0           0  \
# ...
